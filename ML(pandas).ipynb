# %%
import pandas as pd
s1=pd.Series([1,2,3,4,5])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s1[3]
s1[-1]
s1[-2:]
s1[:2]
# Out:
# <ipython-input-6-bc67663c7454>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[3]
# <ipython-input-6-bc67663c7454>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[-1]
# a    1
# b    2
# dtype: int64

# %%
s1+5
# Out:
# a     6
# b     7
# c     8
# d     9
# e    10
# dtype: int64

# %%
s1 = pd.Series([1, 2, 3, 4, 5])  # Changed pd.series to pd.Series
s2 = pd.Series([10, 20, 30, 40, 50])
s1 + s2
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
df=pd.DataFrame({"Name":['bob','sam','Anne'],"marks":[10,20,30]})
df
# Out:
#    Name  marks
# 0   bob     10
# 1   sam     20
# 2  Anne     30

# %%
#using data frames
crime=pd.read_csv('crime.csv')
crime.head()
# Out:
#    Year  Population  Violent crime total  \
# 0  1960   179323175               288460
# 1  1961   182992000               289390
# 2  1962   185771000               301510
# 3  1963   188483000               316970
# 4  1964   191141000               364220
#
#    Murder and nonnegligent Manslaughter  Legacy rape /1  Revised rape /2  \
# 0                                  9110           17190              NaN
# 1                                  8740           17220              NaN
# 2                                  8530           17550              NaN
# 3                                  8640           17650              NaN
# 4                                  9360           21420              NaN
#
#    Robbery  Aggravated assault  Property crime total  Burglary  ...  \
# 0   107840              154320               3095700    912100  ...
# 1   106670              156760               3198600    949600  ...
# ...

# %%
crime.tail()
# Out:
#     Year  Population  Violent crime total  \
# 50  2010   309330219              1251248
# 51  2011   311587816              1206031
# 52  2012   313873685              1217067
# 53  2013   316497531              1199684
# 54  2014   318857056              1197987
#
#     Murder and nonnegligent Manslaughter  Legacy rape /1  Revised rape /2  \
# 50                                 14722           85593              NaN
# 51                                 14661           84175              NaN
# 52                                 14866           85141              NaN
# 53                                 14319           82109         113695.0
# 54                                 14249           84041         116645.0
#
#     Robbery  Aggravated assault  Property crime total  Burglary  ...  \
# 50   369089              781844               9112625   2168459  ...
# 51   354772              752423               9052743   2185140  ...
# ...

# %%
#To find the no of rows and columns
crime.shape
# Out:
# (55, 22)

# %%
#only prints the rows and colums from the specific location
crime.iloc[30:40,10:]
# Out:
#     Larceny-theft  Motor vehicle theft  Violent Crime rate  \
# 30        7945670              1635907               729.6
# 31        8142228              1661738               758.2
# 32        7915199              1610834               757.7
# 33        7820909              1563060               747.1
# 34        7879812              1539287               713.6
# 35        7997710              1472441               684.5
# 36        7904685              1394238               636.6
# 37        7743760              1354189               611.0
# 38        7376311              1242781               567.6
# 39        6955520              1152075               523.0
#
#     Murder and nonnegligent manslaughter rate  Legacy rape rate /1  \
# 30                                        9.4                 41.1
# 31                                        9.8                 42.3
# 32                                        9.3                 42.8
# ...

# %%
#prints required columns
crime.loc[0:,("Year","Aggravated assault","Population")]
# Out:
#     Year  Aggravated assault  Population
# 0   1960              154320   179323175
# 1   1961              156760   182992000
# 2   1962              164570   185771000
# 3   1963              174210   188483000
# 4   1964              203050   191141000
# 5   1965              215330   193526000
# 6   1966              235330   195576000
# 7   1967              257160   197457000
# 8   1968              286700   199399000
# 9   1969              311090   201385000
# 10  1970              334970   203235298
# 11  1971              368760   206212000
# 12  1972              393090   208230000
# 13  1973              420650   209851000
# 14  1974              456210   211392000
# 15  1975              492620   213124000
# 16  1976              500530   214659000
# 17  1977              534350   216332000
# 18  1978              571460   218059000
# 19  1979              629480   220099000
# 20  1980              672650   225349264
# 21  1981              663900   229465714
# ...

# %%
#drop the required colum
crime.drop("Year",axis=1)
# Out:
#     Population  Violent crime total  Murder and nonnegligent Manslaughter  \
# 0    179323175               288460                                  9110
# 1    182992000               289390                                  8740
# 2    185771000               301510                                  8530
# 3    188483000               316970                                  8640
# 4    191141000               364220                                  9360
# 5    193526000               387390                                  9960
# 6    195576000               430180                                 11040
# 7    197457000               499930                                 12240
# 8    199399000               595010                                 13800
# 9    201385000               661870                                 14760
# 10   203235298               738820                                 16000
# 11   206212000               816500                                 17780
# ...

# %%
#drop the rows from the index positions
crime.drop([1,2,3],axis=0)
# Out:
#     Year  Population  Violent crime total  \
# 0   1960   179323175               288460
# 4   1964   191141000               364220
# 5   1965   193526000               387390
# 6   1966   195576000               430180
# 7   1967   197457000               499930
# 8   1968   199399000               595010
# 9   1969   201385000               661870
# 10  1970   203235298               738820
# 11  1971   206212000               816500
# 12  1972   208230000               834900
# 13  1973   209851000               875910
# 14  1974   211392000               974720
# 15  1975   213124000              1039710
# 16  1976   214659000              1004210
# 17  1977   216332000              1029580
# 18  1978   218059000              1085550
# 19  1979   220099000              1208030
# 20  1980   225349264              1344520
# 21  1981   229465714              1361820
# 22  1982   231664458              1322390
# 23  1983   233791994              1258087
# ...

# %%
#pandas function
crime.mean()
crime.min()
crime.max()
crime.median()
crime.std()
# Out:
# Year                                         1.602082e+01
# Population                                   4.165900e+07
# Violent crime total                          4.600798e+05
# Murder and nonnegligent Manslaughter         4.266961e+03
# Legacy rape /1                               2.831620e+04
# Revised rape /2                              2.085965e+03
# Robbery                                      1.505237e+05
# Aggravated assault                           2.963532e+05
# Property crime total                         2.738866e+06
# Burglary                                     7.257360e+05
# Larceny-theft                                1.846694e+06
# Motor vehicle theft                          3.456599e+05
# Violent Crime rate                           1.612661e+02
# Murder and nonnegligent manslaughter rate    1.891585e+00
# Legacy rape rate /1                          9.470519e+00
# Revised rape rate /2                         4.949747e-01
# ...

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with missing values
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [np.nan, 'B', 'A', np.nan, 'C'],
    'C': [10, 20, 30, 40, np.nan]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#      A    B     C
# 0  1.0  NaN  10.0
# 1  2.0    B  20.0
# 2  NaN    A  30.0
# 3  4.0  NaN  40.0
# 4  5.0    C   NaN

# %%
# Mean Imputation for column 'A' and 'C'
df['A'].fillna(df['A'].mean(), inplace=True)
df['C'].fillna(df['C'].mean(), inplace=True)

print("\nDataFrame after Mean Imputation:")
print(df)
# Out:
# DataFrame after Mean Imputation:
#      A    B     C
# 0  1.0  NaN  10.0
# 1  2.0    B  20.0
# 2  3.0    A  30.0
# 3  4.0  NaN  40.0
# 4  5.0    C  25.0
# <ipython-input-8-c6d688d45f57>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(df['A'].mean(), inplace=True)
# <ipython-input-8-c6d688d45f57>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...
